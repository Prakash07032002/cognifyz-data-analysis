# %% [markdown]
# # Cognifyz Technologies - Data Analysis Internship
# (Level 1)
#          ***Name: Prakash***
#          ***Task Level: 1***
# ### Task -1 - ***Top Cuisines***

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
top_cuisines = df['Cuisines'].value_counts().head(3)
print(top_cuisines)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
total = len(df)
percentages = (top_cuisines / total) *100
print(percentages)
# Out:
# Cuisines
# North Indian             9.800021
# North Indian, Chinese    5.350225
# Chinese                  3.706418
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
percentages.plot(kind='bar',color='Skyblue')
plt.title("Top 3 Cuisines by Percentage")
plt.ylabel("Percentage (%)")
plt.xlabel("Cuisines")
plt.show()

# %%
from collections import Counter

# %%
df_clean = df.dropna(subset=['Cuisines'])

# %%
all_cuisines = df_clean['Cuisines'].str.split(',')
flat_cuisines = [cuisine for sublist in all_cuisines for cuisine in sublist]

# %%
cuisines = ["North Indian", "North Indian, Chinese", "Chinese" ]
counts = [936, 511, 354] 
percentages= [9.800021, 5.350225,  3.706418]


plt.figure(figsize=(8,5))
bars = plt.bar(cuisines, percentages,
color=['#1f77b4', '#2ca02c', '#ff7f0e'])

for bar , pct in zip(bars, percentages):
    yuval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2,
           yuval + 1, f'{pct:.2f}%', ha='center')

plt.title("Top 3 Cuisines by Percentage")
plt.ylabel("Percentage (%)")
plt.xlabel("Cuisines")
plt.ylim(0, max(percentages) + 10)
plt.grid(axis='y', linestyle='--',alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# The top 3 cuisines are:
# 1. **North Indian** - 9.80%
# 2. **North Indian, Chinese** - 5.35%
# 3. **Chinese** - 3.71%
#    **North Indian** is the most commonly served Cuisine
#    in the dataset.

# %% [markdown]
# ### level - 1 Task 2: A,Top 10 Cities with Most Restaurent

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")
city_counts = df['City'].value_counts()
print(city_counts.head(10))
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
avg_ratings = df.groupby('City') ['Aggregate rating'].mean().sort_values(ascending=False)
print(avg_ratings.head(10))
# Out:
# City
# Inner City          4.900000
# Quezon City         4.800000
# Makati City         4.650000
# Pasig City          4.633333
# Mandaluyong City    4.625000
# Beechworth          4.600000
# London              4.535000
# Taguig City         4.525000
# Tagaytay City       4.500000
# Secunderabad        4.500000
# Name: Aggregate rating, dtype: float64

# %%
top_city = avg_ratings.idxmax()
top_rating = avg_ratings.max()

print(f"Top-rated city: {top_city} with an "
      f"avg_rating of {top_rating:.2f}")
# Out:
# Top-rated city: Inner City with an avg_rating of 4.90

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")

# %%
sns.set(style="whitegrid")
top_cities_by_count =df['City'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_cities_by_count.values,
            y=top_cities_by_count.index,
            hue=None,
            palette="viridis",
             legend=False
           )
plt.title("Top 10 Cities by Number of Restaurants")
plt.xlabel("Number of Restaurants")  
plt.ylabel("City")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jeevan\AppData\Local\Temp\ipykernel_6192\1653830357.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities_by_count.values,

# %% [markdown]
# ###     The city with the **most restaurant** is:
#            **New Delhi** (5,437 restaurants)

# %% [markdown]
# ### level-1 Task:2 B, Top 10Cities Average Rating

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")

# %%
avg_ratings = df.groupby('City') ['Aggregate rating'].mean().sort_values(ascending=False)
print(avg_ratings.head(10))
# Out:
# City
# Inner City          4.900000
# Quezon City         4.800000
# Makati City         4.650000
# Pasig City          4.633333
# Mandaluyong City    4.625000
# Beechworth          4.600000
# London              4.535000
# Taguig City         4.525000
# Tagaytay City       4.500000
# Secunderabad        4.500000
# Name: Aggregate rating, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.barplot(x=top_10_avg_ratings.index,
            y=top_10_avg_ratings.values,
            hue=None,
            palette='crest',
             legend=False
             )
plt.title("Top 10 Cities by Average Restaurant Rating", fontsize=16)
plt.xlabel("City", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jeevan\AppData\Local\Temp\ipykernel_4776\220221955.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_avg_ratings.index,

# %% [markdown]
# ### The city with the *highest average rating**is:
#         **Inner city** with rating of **4.90**

# %% [markdown]
# ### Level-1 Task-3 Price Range Distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")

# %%
df['Price range'].unique()
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %%
price_counts =df['Price range'].value_counts().sort_index()
print(price_counts)
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
price_percent = (price_counts /
price_counts.sum()) * 100
print(price_percent.round(2))
# Out:
# Price range
# 1    46.53
# 2    32.59
# 3    14.74
# 4     6.14
# Name: count, dtype: float64

# %%
labels = ['Cheap', 'Moderate',  'Expensive',  'Very Expensive']

plt.figure(figsize=(10,7))
fig, ax = plt.subplots(figsize=(10,7R))
wedges, texts, autotexts = ax.pie(price_percent,
                                  labels=None,
                                  autopct='%1.1f%%', 
                                  startangle=140,
                                  colors=sns.color_palette('viridis'))
ax.legend(wedges,labels, loc="center left", bbox_to_anchor=(1,0,0.5,1))
for i,text in enumerate(texts):
    if i == 2:
        text.set_position([text.get_position()[0],text.get_position()[1] -0.1])
plt.title('Percentage of Restaurants by Price Range')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary
#    -The majority of restaurants are in the **Cheap (46.5%)** and
#    **Moderate (32.6%)** categories.
#
#    -Very few restaurants fall into the **Very Expensive (6.1%)** range.
#
#    -This shows that budget-friendly options are more common in this dataset.

# %% [markdown]
# ### Level-1 Task:4 A, Online Delivery Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")

# %%
df['Has Online delivery'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
online_delivery_counts.plot(kind='pie', 
                            autopct='%1.1f%%', startangle=120,
colors=['yellow','lightcoral'])
plt.title("Online Delivery Availability")
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Basic Percentage Calculation:
#       **Yes**: 0.4%
#       **No**: 99.6%

# %% [markdown]
# ### Level-1 task:4 B, Average Ratings Compsarsion

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels = ['No', 'Yes']
ratings = df.groupby('Has Online delivery')['Aggregate rating'].mean()
colors = ['tomato', 'mediumturquoise'] 

plt.figure(figsize=(7,4))
plt.barh(labels, ratings, color=colors, height=0.5)
plt.title("Average Rating: Online Delivery vs No Delivery", fontsize=14, fontweight='bold')
plt.xlabel("Average Rating")
plt.ylabel("Online Delivery")
plt.xlim(0,5)
plt.grid(axis='x', linestyle='--',alpha=0.4)

for i, rating in enumerate(ratings):
    plt.text(rating  + 0.1, i, f"{rating:.2f}",
    va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Based on Online Delivery Rating
#      **Yes = 3.25**
#      **No = 2.47**

# %% [markdown]
#         ---------------------------------XXXXX--------------------------------------------------

# %% [markdown]
# ### Level - 2: Restaurant Ratings
# ### Task 1: A, Analyze disyribution of aggregate Ratings

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")

# %%
df[['Aggregate rating', 'Votes']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Aggregate rating  9551 non-null   float64
#  1   Votes             9551 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 149.4 KB

# %%
df['Votes'] = pd.to_numeric(df['Votes'],errors='coerce')

# %%
rating_counts = df['Aggregate rating'].value_counts().sort_index()
print(rating_counts)
# Out:
# Aggregate rating
# 0.0    2148
# 1.8       1
# 1.9       2
# 2.0       7
# 2.1      15
# 2.2      27
# 2.3      47
# 2.4      87
# 2.5     110
# 2.6     191
# 2.7     250
# 2.8     315
# 2.9     381
# 3.0     468
# 3.1     519
# 3.2     522
# 3.3     483
# 3.4     498
# 3.5     480
# 3.6     458
# 3.7     427
# 3.8     400
# 3.9     335
# 4.0     266
# 4.1     274
# 4.2     221
# 4.3     174
# 4.4     144
# 4.5      95
# 4.6      78
# 4.7      42
# 4.8      25
# 4.9      61
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=rating_counts.values, y=rating_counts.index, palette='Set2')
plt.title("Distribution of Aggregate Ratings",fontsize=14)
plt.xlabel("Number of Restaurants")
plt.ylabel("Aggregate Rating")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jeevan\AppData\Local\Temp\ipykernel_1224\1893896063.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rating_counts.values, y=rating_counts.index, palette='Set2')

# %% [markdown]
# ### Task :1  B, Most common Rating Range

# %%
most_common_rating = rating_counts.idxmax()
print("Most Common Rating:", most_common_rating)
# Out:
# Most Common Rating: 0.0

# %% [markdown]
# ### Task:1 C, Average Number of Votes

# %%
average_votes = df['Votes'].mean()
print("Average Number of Votes:",
      round(average_votes, 2))
# Out:
# Average Number of Votes: 156.91

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Votes'], bins=50, kde=True,color='skyblue')
plt.title("Distribution of Votes Recieved by Restaurants")
plt.xlabel("Votes")
plt.ylabel("Number of Restaurants")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Level-2 Task : 2 A, Most Common Combination of Cuisines

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/InternWork/cognifyz/Dataset.csv")

# %%
df_clean = df.dropna(subset=['Cuisines'])
df_clean['Cuisines']
df_clean['Cuisines'].str.strip().str.title()
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9542, dtype: object

# %%
cuisine_combinations = df_clean['Cuisines'].value_counts()
print("Top 10 Most Common Cuisines Combinations:")
print(cuisine_combinations.head(10))
# Out:
# Top 10 Most Common Cuisines Combinations:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
cuisine_combinations.head(10).plot(kind='barh',color='violet')
plt.title('Top 10 Most Common Cuisines Combinations')
plt.xlabel('Number of Restaurants')
plt.ylabel('Cuisine Combination')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight
#       ***North Indian***  and  ***Chinese*** cuisines are the most frequently offered

# %% [markdown]
# ###  Level- 2 Task:2 B,Most Highest Rated Cuisine

# %%
avg_rating_by_cuisine = df_clean.groupby('Cuisines')['Aggregate rating'].mean()
top_rated_combinations = avg_rating_by_cuisine.sort_values(ascending=False)
print("/n Top 10 Highest Rated Cuisine combinations:")
print(top_rated_combinations.head(10))
# Out:
# /n Top 10 Highest Rated Cuisine combinations:
# Cuisines
# Italian, Deli               4.9
# Hawaiian, Seafood           4.9
# American, Sandwich, Tea     4.9
# Continental, Indian         4.9
# European, Asian, Indian     4.9
# European, Contemporary      4.9
# European, German            4.9
# BBQ, Breakfast, Southern    4.9
# American, Coffee and Tea    4.9
# Sunda, Indonesian           4.9
# Name: Aggregate rating, dtype: float64

# %%
plt.figure(figsize=(10,6))
top_rated_combinations.head(10).plot(kind='barh',color='orange')
plt.title('Top 10 Highest Rated Cuisine Combinations')
plt.xlabel('Average Rating')
plt.ylabel('Cuisine Combination')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights
# ###    All top 10 combinations have an average rating close to ***4.9*** , indicating ***exceptional quality*** and
# ###    ***customer experience***.
